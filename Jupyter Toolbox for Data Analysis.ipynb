# %% [markdown]
# ## Basic Python for Data Analysis
# This material was adapted from https://github.com/dom-devel/pandas_basic_data_analysis_tutorial

# %% [markdown]
# ## How does Jupyter notebook work?
#
# Jupyter notebook (IMO) is the ideal environment for data analysis. It works as follows.
# - You type code into cells.
# - You run the cells.
#
# By breaking the code into cells it allows you to work in steps and investigate the data as you are going.
#
# Jupyter notebook has two modes:
# - Command mode (let's you create new cells, delete them, run them etc.)
# - Edit mode (let's you type into and edit the cells)
#
# Escape takes you to command mode (the highlighted cell will have a blue bar on the left),  Enter takes you to edit mode (the highlighted cell will have a green bar on the left).
#
# While there are buttons at the top, I'd highly recommend learning the shortcuts. Aside from those two the most important are:
#
# **Command Mode:**
# - a: create a cell above
# - b: create a cell below
# - Cmd/Ctrl+Enter - Runs a cell
# - dd: deletes a cell (be careful, you can't undo this)
# - m: Set a cell to text mode (markdown), like this cell you're reading
# - y: Set a cell to code mode (the default)
#
# **Edit mode:**
# - shift+tab: show documentation for the function the cursor is inside. Hit tab multiple times to change where the documentation pop-up appears. (sometimes won't trigger in which case just google "pandas documentation x")

# %%
import pandas as pd
import numpy as np
import re
from IPython.display import display

# %% [markdown]
# **What does this do?:** For our example here, we're going to load in a top 20 ranking file from STAT.
#
# This shows the top 20 rankings domains for a set of keywords and is exactly the data we might want to do some analysis on .
#
# The following function allows us to open a CSV file into a dataframe. That's a fancy word for a table in pandas.
#
# The output of the function on the right is saved into the variable on the left.

# %%
df = pd.read_csv("https://drive.google.com/uc?export=download&id=1w8rAdkdgCIsL06Ub28Hj1B_F2EnCVhjc")
df
# Out:
#                    Keyword Market  Location      Device  \
# 0          0 apr car deals  GB-en       NaN     desktop
# 1          0 apr car deals  GB-en       NaN     desktop
# 2          0 apr car deals  GB-en       NaN     desktop
# 3          0 apr car deals  GB-en       NaN     desktop
# 4          0 apr car deals  GB-en       NaN     desktop
# ...                    ...    ...       ...         ...
# 39595  market value of car  GB-en       NaN  smartphone
# 39596  market value of car  GB-en       NaN  smartphone
# 39597  market value of car  GB-en       NaN  smartphone
# 39598  market value of car  GB-en       NaN  smartphone
# 39599  market value of car  GB-en       NaN  smartphone
#
#        Regional Monthly Search Volume  Rank Result Types for Jan  1, 2017  \
# 0                              1900.0     1                           NaN
# 1                              1900.0     2                           NaN
# 2                              1900.0     3                           NaN
# 3                              1900.0     4                           NaN
# 4                              1900.0     5                           NaN
# ...                               ...   ...                           ...
# 39595                          1300.0    16                       organic
# 39596                          1300.0    17                       organic
# 39597                          1300.0    18                       organic
# 39598                          1300.0    19                       organic
# 39599                          1300.0    20                       organic
#
#       Protocol for Jan  1, 2017  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 39595                      http
# 39596                      http
# 39597                      http
# 39598                     https
# 39599                      http
#
#                              Ranking URL on Jan  1, 2017  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 39595         www.carbase.my/tool/car-market-value-guide
# 39596  www.racq.com.au/cars-and-driving/cars/selling-...
# 39597               m.desperateseller.co.uk/value-my-car
# 39598    www.cargurus.com/Cars/instantMarketValue.action
# 39599                  www.honestjohn.co.uk/used-prices/
#
#       Result Types for Sep  1, 2017 Protocol for Sep  1, 2017  \
# 0                    answers / list                      http
# 1                           organic                     https
# 2                           organic                      http
# 3                           organic                      http
# 4                           organic                     https
# ...                             ...                       ...
# 39595                       organic                     https
# 39596                       organic                      http
# 39597                       organic                      http
# 39598                       organic                     https
# 39599                       organic                     https
#
#                              Ranking URL on Sep  1, 2017  \
# 0      www.autoexpress.co.uk/best-cars/98556/the-best...
# 1      www.carwow.co.uk/best/cars-for-sale-with-0-per...
# 2      www.autoexpress.co.uk/best-cars/98556/the-best...
# 3      www.autoexpress.co.uk/best-cars/85381/best-new...
# 4             www.toyota.co.uk/current-offers/index.json
# ...                                                  ...
# 39595  www.accountingweb.co.uk/any-answers/market-val...
# 39596  www.financial-ombudsman.org.uk/publications/om...
# 39597     www.gocompare.com/car-insurance/vehicle-value/
# 39598                        www.jct600.co.uk/valuation/
# 39599                                  m.redbook.com.au/
#
#                                                     Tags
# 0      !permanent keywords / auto express / featured ...
# 1      !permanent keywords / auto express / featured ...
# 2      !permanent keywords / auto express / featured ...
# 3      !permanent keywords / auto express / featured ...
# 4      !permanent keywords / auto express / featured ...
# ...                                                  ...
# 39595  car valuation / car-valuation / gsc / permanen...
# 39596  car valuation / car-valuation / gsc / permanen...
# 39597  car valuation / car-valuation / gsc / permanen...
# 39598  car valuation / car-valuation / gsc / permanen...
# 39599  car valuation / car-valuation / gsc / permanen...
#
# [39600 rows x 13 columns]

# %% [markdown]
# ## Exploring data
#
# **What does this do?:** This prints out the first x rows of a dataframe

# %%
df.head(1)
# Out:
#            Keyword Market  Location   Device  Regional Monthly Search Volume  \
# 0  0 apr car deals  GB-en       NaN  desktop                          1900.0
#
#    Rank Result Types for Jan  1, 2017 Protocol for Jan  1, 2017  \
# 0     1                           NaN                       NaN
#
#   Ranking URL on Jan  1, 2017 Result Types for Sep  1, 2017  \
# 0                         NaN                answers / list
#
#   Protocol for Sep  1, 2017  \
# 0                      http
#
#                          Ranking URL on Sep  1, 2017  \
# 0  www.autoexpress.co.uk/best-cars/98556/the-best...
#
#                                                 Tags
# 0  !permanent keywords / auto express / featured ...

# %% [markdown]
# **What does this do?:** Gives you the size of the dataframe in rows by columns.

# %%
df.shape
# Out:
# (39600, 13)

# %% [markdown]
# **What does this do?:** Shows you the datatype for each column. (i.e. this column is a string (i.e. text), this column is a number etc.) What is object? For our purposes it's the same as string.

# %%
df.dtypes
# Out:
# Keyword                            object
# Market                             object
# Location                          float64
# Device                             object
# Regional Monthly Search Volume    float64
# Rank                                int64
# Result Types for Jan  1, 2017      object
# Protocol for Jan  1, 2017          object
# Ranking URL on Jan  1, 2017        object
# Result Types for Sep  1, 2017      object
# Protocol for Sep  1, 2017          object
# Ranking URL on Sep  1, 2017        object
# Tags                               object
# dtype: object

# %% [markdown]
# **What does this do?:** This allows you to select a column.
#
# We've also combined it with our previous command so it doesn't print out the entire column.

# %%
df['Market'].head(1)
# Out:
# 0    GB-en
# Name: Market, dtype: object

# %% [markdown]
# **What does this do?:** This shows you all the different values in a column, along with a count of how many there are of each.

# %%
df['Market'].value_counts()
# Out:
# GB-en    39540
# DE-de       60
# Name: Market, dtype: int64

# %% [markdown]
# # Saving results vs printing results out
#
# Each line of code we've had so far has printed something out or saved the result of our calculation into a variable.
#
# If we have a single line of code which doesn't save anything, Jupyter will print out whatever is returned by that line of code.

# %%
df['Market'].head(1)
# Out:
# 0    GB-en
# Name: Market, dtype: object

# %% [markdown]
# If we've saved the results of code into a variable then it won't print anything out.

# %%
saved = df['Market'].head(1)

# %% [markdown]
# We can view the contents of the variable however, by putting the variable by itself into a cell and running that cell.

# %%
saved
# Out:
# 0    GB-en
# Name: Market, dtype: object

# %% [markdown]
# However if you try to print out multiple things at once, by just listing them one by one, then only the past one will be printed.

# %%
df['Market'].head(1)
df['Market'].head(2)
df['Market'].head(3)
"Only I will print."
# Out:
# 'Only I will print.'

# %% [markdown]
# If you do want to print out multiple rows we need to tell pandas. Here its good practice to use display, because often it will make the formatting nicer.

# %%
display(df['Market'].head(1))
display(df['Market'].head(2))
# Out:
# 0    GB-en
# Name: Market, dtype: object
# 0    GB-en
# 1    GB-en
# Name: Market, dtype: object

# %% [markdown]
# # Filtering data
#
# Great so we know how to print out data and how to examine the data we've loaded. What other common tasks might we find outselves doing?
#
# We'll start with filtering. A common use case is wanting to filter data based on the values in columns.

# %% [markdown]
# **What does this do?:** Filter a dataframe based on a string column. In this case we're filtering based on whether or not a regex matches.
#
# We can see the index number on the left changing, because the first row where Keyword contains bmw or audi is 180.

# %%
df_filtered = df[(df["Keyword"].str.contains("bmw|audi", regex=True)==True)]
df_filtered.head(5)
# Out:
#           Keyword Market  Location   Device  Regional Monthly Search Volume  \
# 180  1 series bmw  GB-en       NaN  desktop                          3600.0
# 181  1 series bmw  GB-en       NaN  desktop                          3600.0
# 182  1 series bmw  GB-en       NaN  desktop                          3600.0
# 183  1 series bmw  GB-en       NaN  desktop                          3600.0
# 184  1 series bmw  GB-en       NaN  desktop                          3600.0
#
#      Rank Result Types for Jan  1, 2017 Protocol for Jan  1, 2017  \
# 180     1                       organic                      http
# 181     2                       organic                      http
# 182     3                       organic                      http
# 183     4                       organic                     https
# 184     5                       organic                     https
#
#                         Ranking URL on Jan  1, 2017  \
# 180         www.bmw.co.uk/en_GB/new-vehicles/1.html
# 181     www.autotrader.co.uk/used-cars/bmw/1-series
# 182  www.whatcar.com/bmw/1-series/hatchback/review/
# 183              en.wikipedia.org/wiki/BMW_1_Series
# 184        www.gumtree.com/cars/uk/bmw/bmw+1+series
#
#     Result Types for Sep  1, 2017 Protocol for Sep  1, 2017  \
# 180                       organic                      http
# 181                       organic                     https
# 182                       organic                     https
# 183                       organic                     https
# 184                       organic                     https
#
#                         Ranking URL on Sep  1, 2017  \
# 180         www.bmw.co.uk/en_GB/new-vehicles/1.html
# 181     www.autotrader.co.uk/used-cars/bmw/1-series
# 182            www.gumtree.com/cars/uk/bmw+1+series
# 183  www.whatcar.com/bmw/1-series/hatchback/review/
# 184              en.wikipedia.org/wiki/BMW_1_Series
#
#                            Tags
# 180  temp - semrush / used-cars
# 181  temp - semrush / used-cars
# 182  temp - semrush / used-cars
# 183  temp - semrush / used-cars
# 184  temp - semrush / used-cars

# %% [markdown]
# **What does this do?:** Filter a dataframe based on a numeric column. Here we return all the results for rank 1.

# %%
df_filtered = df[df["Rank"]==1]

# %% [markdown]
# **What does this do?:** Filter a dataframe based on a boolean (i.e. TRUE and FALSE) column. Here we return all the results which are true. We don't have a boolean column yet, so let's quickly create one (we'll go over in more detail later).

# %%
df['is_rank_1'] = False
df.loc[df['Rank'] == 1, 'is_rank_1'] = True

# %% [markdown]
# Then we can filter for any rows where is_rank_1 is equal to True.

# %%
df_filtered = df[df['is_rank_1']]

# %% [markdown]
# If we want to invert this and get any where it doesn't match 1, we do it with `~`

# %%
df_filtered = df[~df['is_rank_1']]

# %% [markdown]
# **What does this do?:** Filter a dataframe based off a list

# %%
list_of_values = [
    '1 series bmw',
    'ford deals'
]
df_filtered = df[df["Keyword"].isin(list_of_values)]

# %% [markdown]
# **What does this do?:** What if we want to use multiple conditions? Again nice and easy, we just put more than one in our first set of square brackets as seen below. `&` is the symbol for and, and `|` is the symbol for or.

# %%
df_filtered = df[(df["Market"].str.contains("GB-en")==False) | 
                 (df["Device"].str.contains("desktop")==True)]

# %% [markdown]
# # Creating new columns based off existing columns

# %% [markdown]
# **What does this do?:** Creates a new column called *Industry* and sets the value to "cars".

# %%
df['industry'] = "Cars"
df.head(5)
# Out:
#            Keyword Market  Location   Device  Regional Monthly Search Volume  \
# 0  0 apr car deals  GB-en       NaN  desktop                          1900.0
# 1  0 apr car deals  GB-en       NaN  desktop                          1900.0
# 2  0 apr car deals  GB-en       NaN  desktop                          1900.0
# 3  0 apr car deals  GB-en       NaN  desktop                          1900.0
# 4  0 apr car deals  GB-en       NaN  desktop                          1900.0
#
#    Rank Result Types for Jan  1, 2017 Protocol for Jan  1, 2017  \
# 0     1                           NaN                       NaN
# 1     2                           NaN                       NaN
# 2     3                           NaN                       NaN
# 3     4                           NaN                       NaN
# 4     5                           NaN                       NaN
#
#   Ranking URL on Jan  1, 2017 Result Types for Sep  1, 2017  \
# 0                         NaN                answers / list
# 1                         NaN                       organic
# 2                         NaN                       organic
# 3                         NaN                       organic
# 4                         NaN                       organic
#
#   Protocol for Sep  1, 2017  \
# 0                      http
# 1                     https
# 2                      http
# 3                      http
# 4                     https
#
#                          Ranking URL on Sep  1, 2017  \
# 0  www.autoexpress.co.uk/best-cars/98556/the-best...
# 1  www.carwow.co.uk/best/cars-for-sale-with-0-per...
# 2  www.autoexpress.co.uk/best-cars/98556/the-best...
# 3  www.autoexpress.co.uk/best-cars/85381/best-new...
# 4         www.toyota.co.uk/current-offers/index.json
#
#                                                 Tags  is_rank_1 industry
# 0  !permanent keywords / auto express / featured ...       True     Cars
# 1  !permanent keywords / auto express / featured ...      False     Cars
# 2  !permanent keywords / auto express / featured ...      False     Cars
# 3  !permanent keywords / auto express / featured ...      False     Cars
# 4  !permanent keywords / auto express / featured ...      False     Cars

# %% [markdown]
# First we'll look at creating a column which is True or False based on a condition. We can use any of the conditions we used in the previous section.
#
# **What does this do?:** Sets the column to True and False based on the filter condition.
#
# Below we're creating a column which is True wherever rank is 1.

# %%
df['is_rank_1'] = df['Rank'] == 1

# %% [markdown]
# Each condition (if you have more than 1) needs to be wrapped in brackets.
#
# Below we're creating a column which is `True` for the all the rows where rank=1 and `False` otherwise.

# %%
df['auto_express_with_rank_2'] = (df['Tags'].str.contains("auto express")) & (df['Rank'] < 4)

# %% [markdown]
# What if we wanted to create a basic search visibility metric? Below we do that by dividing rank by search volume.
#
# **What does this do?:** Below we're creating a column based on a calculation from other columns.

# %%
df['basic_search_visibility'] = df['Regional Monthly Search Volume']/df['Rank']

# %% [markdown]
# Another common usecase, creating a column based off a regex extract. Pandas comes with a built in function for us.
#
# **What does this do?:** This function creates a column, which is the value of the first captured group (everything inside the first set of brackets) in the regex.

# %%
df['car_type'] = df['Keyword'].str.extract("(bmw|audi|ford)", re.IGNORECASE, expand=False)

# %%
df['car_type'].value_counts()
# Out:
# bmw     3660
# audi    2960
# ford    1800
# Name: car_type, dtype: int64

# %% [markdown]
# # Grouping data

# %% [markdown]
# **What does this do?**: This is the most flexible version of groupby. There are simpler syntaxes, but if you know this one you'll be able to do basically everything you want with it. In the example below, we're going to get average rank and total keyword count for each for the later date in our sample (1st Sep 2017).

# %%
df_group = df.groupby('Ranking URL on Sep  1, 2017').agg({
    'Keyword': 'count',
    'Rank': 'mean'
}).reset_index()

# %%
df_group.head()
# Out:
#                          Ranking URL on Sep  1, 2017  Keyword       Rank
# 0                   111.intdmf.com/autolottnotts.com        2  15.500000
# 1                       111.intdmf.com/autolotts.com        2  14.500000
# 2  44teeth.com/contributors/loved-honda-msx-sold-...        2  17.000000
# 3                   4testpass.com/pass-driving-test/        3  12.666667
# 4            a-professional-appraisal.ca/contact-us/        2  19.500000

# %% [markdown]
# Outra maneira de agregação, utilizando uma interface mais simples.

# %%
df_group = df.groupby('Ranking URL on Sep  1, 2017', as_index = False)['Keyword'].count()
df_group.head()
# Out:
#                          Ranking URL on Sep  1, 2017  Keyword
# 0                   111.intdmf.com/autolottnotts.com        2
# 1                       111.intdmf.com/autolotts.com        2
# 2  44teeth.com/contributors/loved-honda-msx-sold-...        2
# 3                   4testpass.com/pass-driving-test/        3
# 4            a-professional-appraisal.ca/contact-us/        2

# %% [markdown]
# # Sorting data

# %% [markdown]
# **What does it do?:** Sorts a dataframe by selecting columns, in the case below we're sorting from biggest to smallest.

# %%
df_group.sort_values(['Keyword'], ascending=False)
# Out:
#                              Ranking URL on Sep  1, 2017  Keyword
# 7163                                   www.google.co.uk/      812
# 5595                      www.confused.com/car-valuation      568
# 3018                  www.autotrader.co.uk/car-valuation      425
# 10030                   www.parkers.co.uk/car-valuation/      412
# 13091                        www.whatcar.com/valuations/      402
# ...                                                  ...      ...
# 9487   www.nationwidevehiclecontracts.co.uk/hot-leasi...        1
# 9486   www.nationwidevehiclecontracts.co.uk/guides/pe...        1
# 9485   www.nationwidevehiclecontracts.co.uk/guides/pe...        1
# 9484   www.nationwidevehiclecontracts.co.uk/guides/ne...        1
# 5788            www.desperateseller.co.uk/cheap-cars/bmw        1
#
# [13414 rows x 2 columns]

# %% [markdown]
# # Displaying more data

# %% [markdown]
# In the case that you do need more columns, rows or wider columns you can set them with the settings below:

# %%
pd.options.display.max_rows = 60
pd.options.display.max_columns = 20
pd.options.display.max_colwidth = 50

# %% [markdown]
# # Joining together multiple datasets

# %% [markdown]
# What if you have more than one dataset and need to join them together? This is a pretty common scenario that we'll now cover.
#
# There are two possible ways we might need to join:
# 1. Joining together two CSVs with the same columns, because our data is split across multiple files
# 2. Joining together a new dataset with our dataset based on matching values (the kind of thing you'd use vlookup or index match for in Excel.
#
# ## 1. Joining together CSV's with the same columns.
#
# For this we've created a fake second dataset that we're going to load and join on the bottom of ours.

# %%
df2 = pd.read_csv("https://drive.google.com/uc?export=download&id=1dGUGIowBzhHQh3IRwSIEOWGqkraT-tEZ")
df2.head()
# Out:
#                   Keyword Market  Location   Device  \
# 0  second keyword dataset  GB-en       NaN  desktop
# 1  second keyword dataset  GB-en       NaN  desktop
# 2  second keyword dataset  GB-en       NaN  desktop
# 3  second keyword dataset  GB-en       NaN  desktop
# 4  second keyword dataset  GB-en       NaN  desktop
#
#    Regional Monthly Search Volume  Rank  Result Types for Jan  1, 2017  \
# 0                            1900     1                            NaN
# 1                            1900     2                            NaN
# 2                            1900     3                            NaN
# 3                            1900     4                            NaN
# 4                            1900     5                            NaN
#
#    Protocol for Jan  1, 2017  Ranking URL on Jan  1, 2017  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
#
#   Result Types for Sep  1, 2017 Protocol for Sep  1, 2017  \
# 0                answers / list                      http
# 1                       organic                     https
# 2                       organic                      http
# 3                       organic                      http
# 4                       organic                     https
#
#                          Ranking URL on Sep  1, 2017  \
# 0  www.autoexpress.co.uk/best-cars/98556/the-best...
# 1  www.carwow.co.uk/best/cars-for-sale-with-0-per...
# 2  www.autoexpress.co.uk/best-cars/98556/the-best...
# 3  www.autoexpress.co.uk/best-cars/85381/best-new...
# 4         www.toyota.co.uk/current-offers/index.json
#
#                                                 Tags
# 0  !permanent keywords / auto express / featured ...
# 1  !permanent keywords / auto express / featured ...
# 2  !permanent keywords / auto express / featured ...
# 3  !permanent keywords / auto express / featured ...
# 4  !permanent keywords / auto express / featured ...

# %% [markdown]
# **What does this do?:** This function takes a list of dataframes and stacks them one on top of the other.

# %%
both_dfs = pd.concat([df, df2])

# %% [markdown]
# We can see how they've been put on top of each other by looking at the size of each individually and the two together.

# %%
print(df.shape)
print(df2.shape)
print(both_dfs.shape)
# Out:
# (39600, 17)
# (20, 13)
# (39620, 17)

# %%
both_dfs.tail(25)
# Out:
#                       Keyword Market  Location      Device  \
# 39595     market value of car  GB-en       NaN  smartphone
# 39596     market value of car  GB-en       NaN  smartphone
# 39597     market value of car  GB-en       NaN  smartphone
# 39598     market value of car  GB-en       NaN  smartphone
# 39599     market value of car  GB-en       NaN  smartphone
# 0      second keyword dataset  GB-en       NaN     desktop
# 1      second keyword dataset  GB-en       NaN     desktop
# 2      second keyword dataset  GB-en       NaN     desktop
# 3      second keyword dataset  GB-en       NaN     desktop
# 4      second keyword dataset  GB-en       NaN     desktop
# 5      second keyword dataset  GB-en       NaN     desktop
# 6      second keyword dataset  GB-en       NaN     desktop
# 7      second keyword dataset  GB-en       NaN     desktop
# 8      second keyword dataset  GB-en       NaN     desktop
# 9      second keyword dataset  GB-en       NaN     desktop
# 10     second keyword dataset  GB-en       NaN     desktop
# 11     second keyword dataset  GB-en       NaN     desktop
# 12     second keyword dataset  GB-en       NaN     desktop
# 13     second keyword dataset  GB-en       NaN     desktop
# 14     second keyword dataset  GB-en       NaN     desktop
# 15     second keyword dataset  GB-en       NaN     desktop
# 16     second keyword dataset  GB-en       NaN     desktop
# 17     second keyword dataset  GB-en       NaN     desktop
# 18     second keyword dataset  GB-en       NaN     desktop
# 19     second keyword dataset  GB-en       NaN     desktop
#
#        Regional Monthly Search Volume  Rank Result Types for Jan  1, 2017  \
# 39595                          1300.0    16                       organic
# 39596                          1300.0    17                       organic
# 39597                          1300.0    18                       organic
# 39598                          1300.0    19                       organic
# 39599                          1300.0    20                       organic
# 0                              1900.0     1                           NaN
# 1                              1900.0     2                           NaN
# 2                              1900.0     3                           NaN
# 3                              1900.0     4                           NaN
# 4                              1900.0     5                           NaN
# 5                              1900.0     6                           NaN
# 6                              1900.0     7                           NaN
# 7                              1900.0     8                           NaN
# 8                              1900.0     9                           NaN
# 9                              1900.0    10                           NaN
# 10                             1900.0    11                           NaN
# 11                             1900.0    12                           NaN
# 12                             1900.0    13                           NaN
# 13                             1900.0    14                           NaN
# 14                             1900.0    15                           NaN
# 15                             1900.0    16                           NaN
# 16                             1900.0    17                           NaN
# 17                             1900.0    18                           NaN
# 18                             1900.0    19                           NaN
# 19                             1900.0    20                           NaN
#
#       Protocol for Jan  1, 2017  \
# 39595                      http
# 39596                      http
# 39597                      http
# 39598                     https
# 39599                      http
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
#
#                              Ranking URL on Jan  1, 2017  \
# 39595         www.carbase.my/tool/car-market-value-guide
# 39596  www.racq.com.au/cars-and-driving/cars/selling-...
# 39597               m.desperateseller.co.uk/value-my-car
# 39598    www.cargurus.com/Cars/instantMarketValue.action
# 39599                  www.honestjohn.co.uk/used-prices/
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
#
#       Result Types for Sep  1, 2017 Protocol for Sep  1, 2017  \
# 39595                       organic                     https
# 39596                       organic                      http
# 39597                       organic                      http
# 39598                       organic                     https
# 39599                       organic                     https
# 0                    answers / list                      http
# 1                           organic                     https
# 2                           organic                      http
# 3                           organic                      http
# 4                           organic                     https
# 5                           organic                      http
# 6                           organic                      http
# 7                           organic                      http
# 8                           organic                      http
# 9                           organic                      http
# 10                          organic                     https
# 11                          organic                     https
# 12                          organic                     https
# 13                          organic                      http
# 14                          organic                     https
# 15                          organic                      http
# 16                          organic                      http
# 17                          organic                      http
# 18                          organic                     https
# 19                          organic                      http
#
#                              Ranking URL on Sep  1, 2017  \
# 39595  www.accountingweb.co.uk/any-answers/market-val...
# 39596  www.financial-ombudsman.org.uk/publications/om...
# 39597     www.gocompare.com/car-insurance/vehicle-value/
# 39598                        www.jct600.co.uk/valuation/
# 39599                                  m.redbook.com.au/
# 0      www.autoexpress.co.uk/best-cars/98556/the-best...
# 1      www.carwow.co.uk/best/cars-for-sale-with-0-per...
# 2      www.autoexpress.co.uk/best-cars/98556/the-best...
# 3      www.autoexpress.co.uk/best-cars/85381/best-new...
# 4             www.toyota.co.uk/current-offers/index.json
# 5                             www.interestfree4cars.com/
# 6      www.thisismoney.co.uk/money/cars/article-42716...
# 7                      www.stoneacre.co.uk/0-car-finance
# 8      www.carbuyer.co.uk/news/81264/best-new-car-dea...
# 9                               www.hyundai.co.uk/offers
# 10     www.mazda.co.uk/aboutmazda/news/mazda-general-...
# 11     www.uk-car-discount.co.uk/news/top-5-0-apr-int...
# 12          www.bristolstreet.co.uk/used-cars/5-years-0/
# 13     m.vauxhall.co.uk/offers/buyers-guide/finance-o...
# 14     www.motoringresearch.com/advice/buying-selling...
# 15     www.mirror.co.uk/money/truth-0-car-finance--10...
# 16         www.parkers.co.uk/car-buying/2017/deal-watch/
# 17               www.mazda.co.uk/offers/offers-overview/
# 18     www.sandicliffe.co.uk/0-finance-used-cars-no-d...
# 19                www.skoda.co.uk/finance/finance-offers
#
#                                                     Tags is_rank_1 industry  \
# 39595  car valuation / car-valuation / gsc / permanen...     False     Cars
# 39596  car valuation / car-valuation / gsc / permanen...     False     Cars
# 39597  car valuation / car-valuation / gsc / permanen...     False     Cars
# 39598  car valuation / car-valuation / gsc / permanen...     False     Cars
# 39599  car valuation / car-valuation / gsc / permanen...     False     Cars
# 0      !permanent keywords / auto express / featured ...       NaN      NaN
# 1      !permanent keywords / auto express / featured ...       NaN      NaN
# 2      !permanent keywords / auto express / featured ...       NaN      NaN
# 3      !permanent keywords / auto express / featured ...       NaN      NaN
# 4      !permanent keywords / auto express / featured ...       NaN      NaN
# 5      !permanent keywords / auto express / featured ...       NaN      NaN
# 6      !permanent keywords / auto express / featured ...       NaN      NaN
# 7      !permanent keywords / auto express / featured ...       NaN      NaN
# 8      !permanent keywords / auto express / featured ...       NaN      NaN
# 9      !permanent keywords / auto express / featured ...       NaN      NaN
# 10     !permanent keywords / auto express / featured ...       NaN      NaN
# 11     !permanent keywords / auto express / featured ...       NaN      NaN
# 12     !permanent keywords / auto express / featured ...       NaN      NaN
# 13     !permanent keywords / auto express / featured ...       NaN      NaN
# 14     !permanent keywords / auto express / featured ...       NaN      NaN
# 15     !permanent keywords / auto express / featured ...       NaN      NaN
# 16     !permanent keywords / auto express / featured ...       NaN      NaN
# 17     !permanent keywords / auto express / featured ...       NaN      NaN
# 18     !permanent keywords / auto express / featured ...       NaN      NaN
# 19     !permanent keywords / auto express / featured ...       NaN      NaN
#
#       auto_express_with_rank_2  basic_search_visibility
# 39595                    False                81.250000
# 39596                    False                76.470588
# 39597                    False                72.222222
# 39598                    False                68.421053
# 39599                    False                65.000000
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# 5                          NaN                      NaN
# 6                          NaN                      NaN
# 7                          NaN                      NaN
# 8                          NaN                      NaN
# 9                          NaN                      NaN
# 10                         NaN                      NaN
# 11                         NaN                      NaN
# 12                         NaN                      NaN
# 13                         NaN                      NaN
# 14                         NaN                      NaN
# 15                         NaN                      NaN
# 16                         NaN                      NaN
# 17                         NaN                      NaN
# 18                         NaN                      NaN
# 19                         NaN                      NaN

# %% [markdown]
# ## 2. Joining together data based on matching values
#
# So previously we've made a poor search visibility metric by multiplying search volume by rank. Now we can make a better search visibility metric by adding in some CTR rate estimates.
#
# We start by loading in our CTR dataset and take a quick look at it.

# %%
ctr = pd.read_csv("https://drive.google.com/uc?export=download&id=1HhfkDTEWYyJdP2IYj1R17qmHWkagOP3n")

# %%
ctr.head(5)
# Out:
#    Rank   Device    CTR
# 0     1  desktop  27.09
# 1     2  desktop  12.61
# 2     3  desktop   8.42
# 3     4  desktop   5.48
# 4     5  desktop   3.84

# %% [markdown]
# Now we need to join CTR with our ranking data. That means we need to match the correct CTR based on both Device and Rank.

# %%
df_with_ctr = pd.merge(df, ctr, how="left", on=["Rank", "Device"])

# %%
df_with_ctr.head(2)
# Out:
#            Keyword Market  Location   Device  Regional Monthly Search Volume  \
# 0  0 apr car deals  GB-en       NaN  desktop                          1900.0
# 1  0 apr car deals  GB-en       NaN  desktop                          1900.0
#
#    Rank Result Types for Jan  1, 2017 Protocol for Jan  1, 2017  \
# 0     1                           NaN                       NaN
# 1     2                           NaN                       NaN
#
#   Ranking URL on Jan  1, 2017 Result Types for Sep  1, 2017  \
# 0                         NaN                answers / list
# 1                         NaN                       organic
#
#   Protocol for Sep  1, 2017  \
# 0                      http
# 1                     https
#
#                          Ranking URL on Sep  1, 2017  \
# 0  www.autoexpress.co.uk/best-cars/98556/the-best...
# 1  www.carwow.co.uk/best/cars-for-sale-with-0-per...
#
#                                                 Tags  is_rank_1 industry  \
# 0  !permanent keywords / auto express / featured ...       True     Cars
# 1  !permanent keywords / auto express / featured ...      False     Cars
#
#    auto_express_with_rank_2  basic_search_visibility    CTR
# 0                      True                   1900.0  27.09
# 1                      True                    950.0  12.61

# %% [markdown]
# ## Re-naming columns

# %%
df.rename(columns={
    'Ranking Full URL on Sep  1, 2017':'2017-09-01', 
    'Ranking Full URL on Jan  1, 2017':'2017-01-01'
}, inplace=True)

# %% [markdown]
# ## Deleting columns
# **What does this do?:** It deletes the list of columns provided. If you set axis=0 then it will try to delete rows. We use inplace=True to delete rows from df_melt rather than return a new dataframe.

# %%
df.drop(['Result Types for Jan  1, 2017', 'Result Types for Sep  1, 2017'], axis=1, inplace=True)

# %%
df.head()
# Out:
#            Keyword Market  Location   Device  Regional Monthly Search Volume  \
# 0  0 apr car deals  GB-en       NaN  desktop                          1900.0
# 1  0 apr car deals  GB-en       NaN  desktop                          1900.0
# 2  0 apr car deals  GB-en       NaN  desktop                          1900.0
# 3  0 apr car deals  GB-en       NaN  desktop                          1900.0
# 4  0 apr car deals  GB-en       NaN  desktop                          1900.0
#
#    Rank Protocol for Jan  1, 2017 Ranking URL on Jan  1, 2017  \
# 0     1                       NaN                         NaN
# 1     2                       NaN                         NaN
# 2     3                       NaN                         NaN
# 3     4                       NaN                         NaN
# 4     5                       NaN                         NaN
#
#   Protocol for Sep  1, 2017  \
# 0                      http
# 1                     https
# 2                      http
# 3                      http
# 4                     https
#
#                          Ranking URL on Sep  1, 2017  \
# 0  www.autoexpress.co.uk/best-cars/98556/the-best...
# 1  www.carwow.co.uk/best/cars-for-sale-with-0-per...
# 2  www.autoexpress.co.uk/best-cars/98556/the-best...
# 3  www.autoexpress.co.uk/best-cars/85381/best-new...
# 4         www.toyota.co.uk/current-offers/index.json
#
#                                                 Tags  is_rank_1 industry  \
# 0  !permanent keywords / auto express / featured ...       True     Cars
# 1  !permanent keywords / auto express / featured ...      False     Cars
# 2  !permanent keywords / auto express / featured ...      False     Cars
# 3  !permanent keywords / auto express / featured ...      False     Cars
# 4  !permanent keywords / auto express / featured ...      False     Cars
#
#    auto_express_with_rank_2  basic_search_visibility
# 0                      True              1900.000000
# 1                      True               950.000000
# 2                      True               633.333333
# 3                     False               475.000000
# 4                     False               380.000000
